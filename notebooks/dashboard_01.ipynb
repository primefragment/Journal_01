# %% [markdown]
# # Dashboard

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the CSV file into a DataFrame
df = pd.read_csv('..\data\daily_journal.csv')

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['6am Club'])
plt.title('6am Club')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\LocalUser\AppData\Local\Temp\ipykernel_9292\3231072416.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df = pd.read_csv('..\data\daily_journal.csv')
# C:\Users\LocalUser\AppData\Local\Temp\ipykernel_9292\3231072416.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
